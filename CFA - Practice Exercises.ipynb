# %%
# yfinance is an open-source tool used to get market data from Yahoo 

# !pip install yfinance
import yfinance as yf 
import pandas as pd 
import datetime
# Out:
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'c:\\users\\karina\\miniconda3\\lib\\site-packages\\numpy-1.21.2.dist-info\\METADATA'
# Requirement already satisfied: yfinance in c:\users\karina\miniconda3\lib\site-packages (0.2.12)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\karina\miniconda3\lib\site-packages (from yfinance) (1.3.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\karina\miniconda3\lib\site-packages (from yfinance) (1.21.2)
# Collecting requests>=2.26 (from yfinance)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\karina\miniconda3\lib\site-packages (from yfinance) (0.0.9)
# Collecting lxml>=4.9.1 (from yfinance)
#   Downloading lxml-5.2.2-cp39-cp39-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\karina\miniconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\karina\miniconda3\lib\site-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\karina\miniconda3\lib\site-packages (from yfinance) (2.3.5)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\karina\miniconda3\lib\site-packages (from yfinance) (37.0.1)
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: html5lib>=1.1 in c:\users\karina\miniconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\karina\miniconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.2.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\karina\miniconda3\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in c:\users\karina\miniconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\karina\miniconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)

# %% [markdown]
# # Capital Asset Pricing Model

# %% [markdown]
# - **Assume that you work as a financial analyst and you have been tasked to develop a Python application that analyzes securities using the Capital Asset Pricing Model (CAPM).**
#     - **1. Review the concept of CAPM and write down the formula**
#     - **2. Write a Python code that will recieve beta for a given stock, risk-free rate and expected broad market return from the user and prints out the expected return on the stock. Round your answer to two decimal points.**
#
# - **A sample code output is as shown below:**
#     - Please enter the name of the stock: Apple
#     - Enter the stock beta: 1.25
#     - Enter the risk-free rate of return in %: 4
#     - Enter the expected broad market rate of return in % (Ex: S&P500): 5.6
#     - Using the CAPM formula, the expected return on Apple stock = 6.0%

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
stock = input('Please enter the name of the stock: ')
beta = float(input('Enter the stock beta: '))
risk_free_rate = float(input('Enter the risk-free rate of return in %: '))
market_return = float(input('Enter the expected broad market rate of return in % (Ex: S&P500): '))
expected_return = risk_free_rate + beta * (market_return - risk_free_rate)
print('Using the CAPM formula, the expected return on {} stock = {}%'.format(stock, round(expected_return, 2)))
# Out:
# Please enter the name of the stock: Apple
# Enter the stock beta: 1.25
# Enter the risk-free rate of return in %: 4
# Enter the expected broad market rate of return in % (Ex: S&P500): 5.6
# Using the CAPM formula, the expected return on Apple stock = 6.0%

# %% [markdown]
# # Dividend Discount Model

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - **Consider a company XYZ Inc. whose stock is currently trading at \\$64 per share. The company requires a 14% minimum rate of return (r) and pays a dividend of $2 dividend per share this year (D0), which is expected to increase by 10% annually (g).**
#
#     - **1. Review the Dividend Discount Model and write down the formula**
#     - **2. Calculate the intrinsic value (P) of the stock**
#     - **3. Assume that you are evaluating whether to invest in XYZ Inc. or not. Write a Python code that compares the current intinsic value to the stock price and prints out one of the following recommendations: overvalued, undervalued, or fairly valued**
#     - **4. Expand the code so users can enter the current stock price, minimum rate of return, current dividend, and annual growth and print out the recommendation to the screen**
#
# - **A sample code output is as shown below:**
#     - Enter this year's dividend: 2
#     - Enter the company's expected dividend growth: 0.1
#     - Enter the company's cost of equity: 0.14
#     - Enter the current stock price: 64
#     - The stock value based on the Dividend Discount Model = $55.0
#     - Stock is overvalued, you should not invest in this stock

# %%
# Defining the current market price for a given company
current_market_price = 64

# Defining current (this year's) dividend
dividend_0 = 2

# Defining the expected dividend growth
growth = 0.1

# Defining the cost of equity
cost_of_equity = 0.14

# Calculating next year's dividend dividend_1
dividend_1 = dividend_0 * (1 + growth)

# Performing stock valuation using the dividend discount model 
stock_valuation = dividend_1 / (cost_of_equity - growth) 
print("The stock value based on the Dividend Discount Model = ${}".format(round(stock_valuation, 2)))

# Comparing the stock valuation (based on the dividend growth model) to the current stock price
if current_market_price > stock_valuation:
    print("Stock is overvalued, you should not invest in this stock")
    
elif current_market_price < stock_valuation:
    print("Stock is undervalued, you should invest in this stock")
    
else:
    print('Stock is fairly valued')
# Out:
# The stock value based on the Dividend Discount Model = $55.0

# %%
dividend_0           = float(input("Enter this year's dividend: "))
growth               = float(input("Enter the company's expected dividend growth: "))
cost_of_equity       = float(input("Enter the company's cost of equity: "))
current_market_price = float(input("Enter the current stock price: "))


# Calculating next year's dividend dividend_1
dividend_1 = dividend_0 * (1 + growth)


# Performing stock valuation using the dividend discount model 
stock_valuation = dividend_1 / (cost_of_equity - growth) 
print("The stock value based on the Dividend Discount Model = ${}".format(round(stock_valuation, 2)))


# Comparing the stock valuation (based on the dividend growth model) to the current stock price
if current_market_price > stock_valuation:
    print("Stock is overvalued, you should not invest in this stock")
    
elif current_market_price < stock_valuation:
    print("Stock is undervalued, you should invest in this stock")
    
else:
    print('Stock is fairly valued')
# Out:
# Enter this year's dividend: 2
# Enter the company's expected dividend growth: 0.1
# Enter the company's cost of equity: 0.14
# Enter the current stock price: 64
# The stock value based on the Dividend Discount Model = $55.0
# Stock is overvalued, you should not invest in this stock

# %% [markdown]
# # Future Value Calculations

# %% [markdown]
# **PRACTICE OPPORTUNITY SOLUTION:**
#
# - **Write a Python code that performs the following tasks:**
#      - **1. Takes in the present value, annual interest rate and expected future value from the user.**
#      - **2. Calculates the total number of years it would take to reach a given expected future value. Round your answer to the nearest year and print it to the screen.**
#      - **3. Prints the future value at the end of each year as shown below.**
#
#
# - **Sample Expected Output:**
#
#         Enter the amount of funds you would like to invest today in dollars (Present Value (PV)): 1000
#         Enter the annual interest rate: 0.1
#         Enter the total dollar amount you would like to have in the future (Future Value (FV)): 2000
#
#         The Present Value (PV) in year 0 (now) = $1000.0
#
#         Future Value (FV) in year 1 = $1100.0
#
#         Future Value (FV) in year 2 = $1210.0
#
#         Future Value (FV) in year 3 = $1331.0
#
#         Future Value (FV) in year 4 = $1464.1
#
#         Future Value (FV) in year 5 = $1610.5
#
#         Future Value (FV) in year 6 = $1771.6
#
#         Future Value (FV) in year 7 = $1948.7
#
#         Future Value (FV) in year 8 = $2143.6
#
#         It would take around 8 years to reach a future value greater than 2000.0

# %%
# Note that amount is the Present Value 
# You can name the variable "present_value" instead of "amount"

amount = float(input("Enter the amount of funds you would like to invest today in dollars (Present Value (PV)): "))
interest = float(input("Enter the annual interest rate: "))
future_value = float(input("Enter the total dollar amount you would like to have in the future (Future Value (FV)): "))

years = 1

print('The Present Value (PV) in year 0 (Now) = ${}'.format(round(amount, 1)))


while True:
    amount = amount + (interest * amount)
    print('Future Value (FV) in year {} = ${}'.format(years, round(amount, 1)))
    
    # Condition to break the loop here
    if amount > future_value:
        print('It would take around {} years to reach a future value greater than {}'.format(years, future_value))
        break
    years = years + 1
# Out:
# Enter the amount of funds you would like to invest today in dollars (Present Value (PV)): 1000
# Enter the annual interest rate: 0.1
# Enter the total dollar amount you would like to have in the future (Future Value (FV)): 2000
# The Present Value (PV) in year 0 (Now) = $1000.0
# Future Value (FV) in year 1 = $1100.0
# Future Value (FV) in year 2 = $1210.0
# Future Value (FV) in year 3 = $1331.0
# Future Value (FV) in year 4 = $1464.1
# Future Value (FV) in year 5 = $1610.5
# Future Value (FV) in year 6 = $1771.6
# Future Value (FV) in year 7 = $1948.7
# Future Value (FV) in year 8 = $2143.6
# It would take around 8 years to reach a future value greater than 2000.0

# %% [markdown]
# # Get Financial Data

# %%
# Using Yahoo Finance tool to fetch all data related to stock of interest
stock = yf.Ticker("AAPL")

# Recommendations indicate analyst's ratings
# Info returns company information in a dictionary format
stock.info
# Out:
# - AAPL: No summary info found, symbol may be delisted
# None

# %%
# Beta is a measure of the security volatility compared to the market (S&P 500) 
# Stocks with betas greater than 1.0 are more volatile compared to S&P 500 
print("The company beta is = {}".format(stock.info['beta']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 4>()
#       1 # Let's obtain the company beta
#       2 # Remember that Beta is a measure of the security volatility compared to the market (S&P 500)
#       3 # Stocks with betas greater than 1.0 are more volatile compared to S&P 500
# ----> 4 print("The company beta is = {}".format(stock.info['beta']))
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Free cash flow is the cash left in a company after it pays for its operating and capital expenditures.
print("The company cash is = ${}".format(stock.info['freeCashflow']))

# %%
# Price-to-Earnings (P/E) ratio is calculated by dividing the current share price by its earnings per share (EPS) 
# High price-to-earnings ratio could indicate that the company's stock is overvalued 
# Example: S&P500 P/E ratio ranged from 5x in 1917 to 120x in 2009 right before the financial crisis 
# Trailing P/E is calculated using past performance by dividing the current stock price by total EPS earnings over the past 12 months.
print("The company Price-to-Earnings (P/E) ratio is = {} ".format(stock.info['trailingPE']))

# %%
# Obtaining cash flow statements
stock.get_cashflow()

# %%
# Viewing some recommendations
stock.recommendations.tail(20)

# %%
# Using Yahoo Finance tool to fetch stock data
# Actions is used to obtain dividends and stock splits 
dividends_splits_df = stock.actions
dividends_splits_df

# %%
# Obtaining the balance sheet for Apple
balance_df = stock.get_balance_sheet()
balance_df.round()

# %%
# Specify the starting date 
startDate = datetime.datetime(2021, 3, 1)
 
# Specify the end date 
endDate = datetime.datetime(2022, 3, 1)
 
# Obtain the stock price data
print(stock.history(start = startDate, end = endDate))
